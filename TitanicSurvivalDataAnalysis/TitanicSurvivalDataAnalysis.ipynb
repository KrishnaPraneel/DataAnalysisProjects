# %%
import warnings 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.style.use('fivethirtyeight') 
# %matplotlib inline 
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('/Users/krishnapeddibhotla/Downloads/titanic/train.csv') 
test = pd.read_csv('/Users/krishnapeddibhotla/Downloads/titanic/test.csv') 

# To know number of columns and rows 
train.shape
# Out:
# (891, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'train' is your DataFrame containing the 'Survived' column

# Create subplots
f, ax = plt.subplots(1, 2, figsize=(12, 4))

# Pie chart
train['Survived'].value_counts().plot.pie(
    explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=False)
ax[0].set_title('Survivors (1) and the dead (0)')
ax[0].set_ylabel('')  # Clear y-axis label

# Count plot
sns.countplot(x='Survived', data=train, ax=ax[1])
ax[1].set_ylabel('Quantity')
ax[1].set_title('Survivors (1) and the dead (0)')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'train' is your DataFrame containing 'Sex' and 'Survived' columns

# Create subplots
f, ax = plt.subplots(1, 2, figsize=(12, 4))

# Bar plot of average survival rate by sex
train[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survivors by sex')

# Count plot of survivors and deceased by sex
sns.countplot(x='Sex', hue='Survived', data=train, ax=ax[1])
ax[1].set_ylabel('Quantity')
ax[1].set_title('Survived (1) and deceased (0): men and women')

# Show plot
plt.show()
